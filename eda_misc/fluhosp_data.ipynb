# %%
Flu Hospitalizations Data EDA

# %%
import pandas as pd
from sodapy import Socrata
import matplotlib.pyplot as plt
import numpy as np

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("healthdata.gov", None)
# dictionaries by sodapy.
results = client.get("anag-cw7u",limit=50000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# results_df
# can't load more than 50000 rows so I manually downloaded and read the while csv in
prev_results_df = pd.read_csv("./fluhosp_dat.csv")
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df = pd.DataFrame.from_records(results)
results_df.head()
# Out:
#   hospital_pk          collection_week state     ccn  \
# 0      100075  2021-10-08T00:00:00.000    FL  100075
# 1      503300  2021-10-08T00:00:00.000    WA  503300
# 2      140181  2021-10-08T00:00:00.000    IL  140181
# 3      241303  2021-10-08T00:00:00.000    MN  241303
# 4      521358  2021-10-08T00:00:00.000    WI  521358
#
#                   hospital_name                                address  \
# 0           ST JOSEPHS HOSPITAL      3001 W MARTIN LUTHER KING JR BLVD
# 1   SEATTLE CHILDREN'S HOSPITAL  4800 SAND POINT WAY NE, PO BOX C-5371
# 2          SOUTH SHORE HOSPITAL              8012 SOUTH CRANDON AVENUE
# 3  SANFORD TRACY MEDICAL CENTER                  251 FIFTH STREET EAST
# 4    DOOR COUNTY MEDICAL CENTER                  323 SOUTH 18TH AVENUE
#
#            city    zip           hospital_subtype fips_code  ...  \
# 0         TAMPA  33677                 Short Term     12057  ...
# 1       SEATTLE  98105        Childrens Hospitals     53033  ...
# 2       CHICAGO  60617                 Short Term     17031  ...
# 3         TRACY  56175  Critical Access Hospitals     27083  ...
# 4  STURGEON BAY  54235  Critical Access Hospitals     55029  ...
#
#   previous_day_admission_pediatric_covid_suspected_7_day_coverage  \
# 0                                                  7
# 1                                                  7
# 2                                                  1
# 3                                                  7
# 4                                                  7
#
#   previous_week_personnel_covid_vaccinated_doses_administered_7_day  \
# 0                                               4932
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                 22
#
#   total_personnel_covid_vaccinated_doses_none_7_day  \
# 0                                              4456
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                                55
#
#   total_personnel_covid_vaccinated_doses_one_7_day  \
# 0                                             4913
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              688
#
#   total_personnel_covid_vaccinated_doses_all_7_day  \
# 0                                             4932
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              639
#
#   previous_week_patients_covid_vaccinated_doses_one_7_day  \
# 0                                                  0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                 20
#
#   previous_week_patients_covid_vaccinated_doses_all_7_day is_corrected  \
# 0                                                  0             False
# 1                                                NaN             False
# 2                                                NaN             False
# 3                                                NaN             False
# 4                                                 17             False
#
#                            geocoded_hospital_address  \
# 0                                                NaN
# 1  {'type': 'Point', 'coordinates': [-122.283169,...
# 2  {'type': 'Point', 'coordinates': [-87.568623, ...
# 3  {'type': 'Point', 'coordinates': [-95.60675, 4...
# 4  {'type': 'Point', 'coordinates': [-87.351418, ...
#
#   :@computed_region_pqdx_y6mm
# 0                         NaN
# 1                          48
# 2                          14
# 3                          24
# 4                          50
#
# [5 rows x 107 columns]

# %%
prev_results_df.head()
# Out:
#   hospital_pk collection_week state     ccn  \
# 0      102024      2021/09/17    FL  102024
# 1      172007      2021/09/17    KS  172007
# 2      190245      2021/09/17    LA  190245
# 3      222023      2021/09/17    MA  222023
# 4      050766      2021/09/10    CA  050766
#
#                              hospital_name  \
# 0      SELECT SPECIALTY HOSPITAL PENSACOLA
# 1        SELECT SPECIALTY HOSPITAL WICHITA
# 2                 MONROE SURGICAL HOSPITAL
# 3           WESTERN MASSACHUSETTS HOSPITAL
# 4  SUTTER SURGICAL HOSPITAL - NORTH VALLEY
#
#                                         address       city      zip  \
# 0                          7000 COBBLE CREEK DR  PENSACOLA  32504.0
# 1  929 NORTH ST FRANCIS, 6TH FLOOR, NORTH TOWER    WICHITA  67214.0
# 2                           2408 BROADMOOR BLVD     MONROE  71201.0
# 3                         91 EAST MOUNTAIN ROAD  WESTFIELD   1085.0
# 4                               455 PLUMAS BLVD  YUBA CITY  95991.0
#
#   hospital_subtype  fips_code  ...  \
# 0        Long Term    12033.0  ...
# 1        Long Term    20173.0  ...
# 2       Short Term    22073.0  ...
# 3        Long Term    25013.0  ...
# 4       Short Term     6101.0  ...
#
#    previous_day_admission_pediatric_covid_confirmed_7_day_coverage  \
# 0                                                  7
# 1                                                  7
# 2                                                  7
# 3                                                  7
# 4                                                  7
#
#    previous_day_admission_adult_covid_suspected_7_day_coverage  \
# 0                                                  7
# 1                                                  7
# 2                                                  7
# 3                                                  7
# 4                                                  7
#
#    previous_day_admission_pediatric_covid_suspected_7_day_coverage  \
# 0                                                  7
# 1                                                  7
# 2                                                  7
# 3                                                  7
# 4                                                  7
#
#    previous_week_personnel_covid_vaccinated_doses_administered_7_day  \
# 0                                                NaN
# 1                                                NaN
# 2                                                0.0
# 3                                                NaN
# 4                                                0.0
#
#    total_personnel_covid_vaccinated_doses_none_7_day  \
# 0                                                NaN
# 1                                                NaN
# 2                                              117.0
# 3                                                NaN
# 4                                                0.0
#
#    total_personnel_covid_vaccinated_doses_one_7_day  \
# 0                                               NaN
# 1                                               NaN
# 2                                              30.0
# 3                                               NaN
# 4                                               0.0
#
#    total_personnel_covid_vaccinated_doses_all_7_day  \
# 0                                               NaN
# 1                                               NaN
# 2                                         -999999.0
# 3                                               NaN
# 4                                               0.0
#
#    previous_week_patients_covid_vaccinated_doses_one_7_day  \
# 0                                                NaN
# 1                                                NaN
# 2                                                0.0
# 3                                                NaN
# 4                                                0.0
#
#    previous_week_patients_covid_vaccinated_doses_all_7_day  is_corrected
# 0                                                NaN               False
# 1                                                NaN               False
# 2                                                0.0               False
# 3                                                NaN               False
# 4                                                0.0               False
#
# [5 rows x 106 columns]

# %%
# some summary statistics
num_rows = results_df.shape[0]
num_rows
# Out:
# 304651

# %%
num_cols = results_df.shape[1]
num_cols
# Out:
# 106

# %%
# missing values in the truth (numbers of confirmed influenza admissions)
results_df.iloc[:,34].isna().sum()
# Out:
# 3308

# %%
# unique years in data
pd.Series(results_df['collection_week']).unique()
# Out:
# array(['2021/09/17', '2021/09/10', '2021/09/03', '2021/08/27',
#        '2021/08/20', '2021/08/13', '2021/08/06', '2021/07/30',
#        '2021/07/23', '2021/07/09', '2021/07/02', '2021/06/25',
#        '2021/06/18', '2021/06/11', '2021/06/04', '2021/05/28',
#        '2021/05/21', '2021/05/14', '2021/05/07', '2021/04/30',
#        '2021/04/23', '2021/04/16', '2021/04/09', '2021/04/02',
#        '2021/03/26', '2021/03/19', '2021/03/12', '2021/03/05',
#        '2021/02/26', '2021/02/19', '2021/02/12', '2021/02/05',
#        '2021/01/29', '2021/01/22', '2021/01/15', '2021/01/08',
#        '2021/01/01', '2020/12/25', '2020/12/18', '2020/12/04',
#        '2020/11/27', '2020/11/20', '2020/11/13', '2020/11/06',
#        '2020/10/30', '2020/10/23', '2020/10/16', '2020/10/09',
#        '2020/10/02', '2020/09/25', '2020/09/18', '2020/09/11',
#        '2020/09/04', '2020/08/28', '2020/08/21', '2020/08/14',
#        '2020/08/07', '2020/07/31', '2021/09/24', '2021/07/16',
#        '2020/12/11'], dtype=object)

# %%
# missing values after aggregating over states

# %%
# truth by state
# not sure what  the negative number is, but threw them out for now
filtered_df = results_df.iloc[:,[1,2,34]][(results_df.iloc[:,34])>0].dropna().groupby(['state','collection_week'],as_index=False).sum()
filtered_df
# Out:
#      state collection_week  \
# 0       AK      2020/07/31
# 1       AK      2020/08/07
# 2       AK      2020/08/14
# 3       AK      2020/08/21
# 4       AK      2020/08/28
# ...    ...             ...
# 3345    WY      2021/08/27
# 3346    WY      2021/09/03
# 3347    WY      2021/09/10
# 3348    WY      2021/09/17
# 3349    WY      2021/09/24
#
#       all_adult_hospital_inpatient_bed_occupied_7_day_sum
# 0                                                3568.0
# 1                                                3144.0
# 2                                                3663.0
# 3                                                3468.0
# 4                                                3501.0
# ...                                                 ...
# 3345                                             4348.0
# 3346                                             4292.0
# 3347                                             4608.0
# 3348                                             4353.0
# 3349                                             4609.0
#
# [3350 rows x 3 columns]

# %%
plotdf = filtered_df.pivot(index='collection_week', columns='state', values='all_adult_hospital_inpatient_bed_occupied_7_day_sum')
plotdf
# Out:
# state                AK       AL       AR     AS       AZ        CA       CO  \
# collection_week
# 2020/07/31       3568.0  68577.0  26982.0    NaN  43933.0  268488.0  25951.0
# 2020/08/07       3144.0  67119.0  26393.0    NaN  41167.0  260386.0  25907.0
# 2020/08/14       3663.0  67020.0  27237.0    NaN  41626.0  266432.0  25847.0
# 2020/08/21       3468.0  67724.0  26534.0    NaN  41294.0  270378.0  25745.0
# 2020/08/28       3501.0  63799.0  27614.0    NaN  39879.0  270872.0  30869.0
# ...                 ...      ...      ...    ...      ...       ...      ...
# 2021/08/27       4929.0  71292.0  36702.0  440.0  66796.0  313134.0  44637.0
# 2021/09/03       4845.0  70745.0  36139.0  443.0  64642.0  305481.0  43871.0
# 2021/09/10       5115.0  71235.0  37309.0  437.0  65525.0  311375.0  45541.0
# 2021/09/17       5080.0  68845.0  36295.0  402.0  66188.0  307049.0  45231.0
# 2021/09/24       5143.0  59889.0  35475.0  398.0  66845.0  301840.0  45085.0
#
# state                 CT       DC       DE  ...       TN        TX       UT  \
# collection_week                             ...
# 2020/07/31       27294.0  10719.0   2572.0  ...  65339.0  242301.0  16993.0
# 2020/08/07       28468.0  11855.0   7692.0  ...  67152.0  260878.0  16788.0
# 2020/08/14       28415.0  12246.0   8022.0  ...  69853.0  275583.0  16113.0
# 2020/08/21       37171.0  12066.0   8735.0  ...  68376.0  261755.0  16400.0
# 2020/08/28       36902.0  12659.0   8753.0  ...  71786.0  268717.0  16118.0
# ...                  ...      ...      ...  ...      ...       ...      ...
# 2021/08/27       40327.0  12357.0  12760.0  ...  80173.0  306560.0  20597.0
# 2021/09/03       40450.0  12400.0  12611.0  ...  80092.0  305529.0  19986.0
# 2021/09/10       41586.0  12780.0  13238.0  ...  82093.0  311542.0  20805.0
# 2021/09/17       40949.0  12612.0  12677.0  ...  80989.0  310306.0  20733.0
# 2021/09/24       40540.0  12462.0  12760.0  ...  79700.0  300611.0  20451.0
#
# state                 VA     VI      VT       WA       WI       WV      WY
# collection_week
# 2020/07/31       51309.0  548.0   961.0  48341.0  40386.0  24733.0  2606.0
# 2020/08/07       53020.0  579.0   850.0  44093.0  41694.0  25253.0  3142.0
# 2020/08/14       47235.0  626.0  1051.0  32466.0  42992.0  25987.0  2032.0
# 2020/08/21       48971.0  579.0  1077.0  40512.0  43030.0  25183.0  3126.0
# 2020/08/28       54428.0  644.0  1343.0  49028.0  43240.0  25173.0  2079.0
# ...                  ...    ...     ...      ...      ...      ...     ...
# 2021/08/27       77786.0  580.0  5424.0  57547.0  51208.0  26451.0  4348.0
# 2021/09/03       77961.0  618.0  5156.0  57630.0  50823.0  26125.0  4292.0
# 2021/09/10       80304.0  668.0  5328.0  58296.0  52377.0  26113.0  4608.0
# 2021/09/17       79048.0  699.0  5337.0  58140.0  52312.0  25925.0  4353.0
# 2021/09/24       77843.0  640.0  5435.0  57847.0  52950.0  26116.0  4609.0
#
# [61 rows x 56 columns]

# %%
# state with missing values after aggregating across facilities..
plotdf.columns[plotdf.isnull().any()]
# surprisingly only 2 states
# Out:
# Index(['AS', 'MP'], dtype='object', name='state')

# %%
filtered_df = results_df.iloc[:,[1,2,34]][(results_df.iloc[:,34])>0].dropna().groupby(['state','collection_week'],as_index=False).sum()
filtered_df
