# %%
Flu Hospitalizations RNN

# %%
import pandas as pd
from sodapy import Socrata
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers


# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
#client = Socrata("healthdata.gov", None)

# dictionaries by sodapy.
# results = client.get("anag-cw7u",limit=50000)

# Convert to pandas DataFrame
# results_df = pd.DataFrame.from_records(results)
# results_df
# can't load more than 50000 rows so I manually downloaded and read the while csv in
results_df = pd.read_csv("./fluhosp_dat.csv")
results_df.head()
# Out:
#   hospital_pk collection_week state     ccn  \
# 0      102024      2021/09/17    FL  102024
# 1      172007      2021/09/17    KS  172007
# 2      190245      2021/09/17    LA  190245
# 3      222023      2021/09/17    MA  222023
# 4      050766      2021/09/10    CA  050766
#
#                              hospital_name  \
# 0      SELECT SPECIALTY HOSPITAL PENSACOLA
# 1        SELECT SPECIALTY HOSPITAL WICHITA
# 2                 MONROE SURGICAL HOSPITAL
# 3           WESTERN MASSACHUSETTS HOSPITAL
# 4  SUTTER SURGICAL HOSPITAL - NORTH VALLEY
#
#                                         address       city      zip  \
# 0                          7000 COBBLE CREEK DR  PENSACOLA  32504.0
# 1  929 NORTH ST FRANCIS, 6TH FLOOR, NORTH TOWER    WICHITA  67214.0
# 2                           2408 BROADMOOR BLVD     MONROE  71201.0
# 3                         91 EAST MOUNTAIN ROAD  WESTFIELD   1085.0
# 4                               455 PLUMAS BLVD  YUBA CITY  95991.0
#
#   hospital_subtype  fips_code  ...  \
# 0        Long Term    12033.0  ...
# 1        Long Term    20173.0  ...
# 2       Short Term    22073.0  ...
# 3        Long Term    25013.0  ...
# 4       Short Term     6101.0  ...
#
#    previous_day_admission_pediatric_covid_confirmed_7_day_coverage  \
# 0                                                  7
# 1                                                  7
# 2                                                  7
# 3                                                  7
# 4                                                  7
#
#    previous_day_admission_adult_covid_suspected_7_day_coverage  \
# 0                                                  7
# 1                                                  7
# 2                                                  7
# 3                                                  7
# 4                                                  7
#
#    previous_day_admission_pediatric_covid_suspected_7_day_coverage  \
# 0                                                  7
# 1                                                  7
# 2                                                  7
# 3                                                  7
# 4                                                  7
#
#    previous_week_personnel_covid_vaccinated_doses_administered_7_day  \
# 0                                                NaN
# 1                                                NaN
# 2                                                0.0
# 3                                                NaN
# 4                                                0.0
#
#    total_personnel_covid_vaccinated_doses_none_7_day  \
# 0                                                NaN
# 1                                                NaN
# 2                                              117.0
# 3                                                NaN
# 4                                                0.0
#
#    total_personnel_covid_vaccinated_doses_one_7_day  \
# 0                                               NaN
# 1                                               NaN
# 2                                              30.0
# 3                                               NaN
# 4                                               0.0
#
#    total_personnel_covid_vaccinated_doses_all_7_day  \
# 0                                               NaN
# 1                                               NaN
# 2                                         -999999.0
# 3                                               NaN
# 4                                               0.0
#
#    previous_week_patients_covid_vaccinated_doses_one_7_day  \
# 0                                                NaN
# 1                                                NaN
# 2                                                0.0
# 3                                                NaN
# 4                                                0.0
#
#    previous_week_patients_covid_vaccinated_doses_all_7_day  is_corrected
# 0                                                NaN               False
# 1                                                NaN               False
# 2                                                0.0               False
# 3                                                NaN               False
# 4                                                0.0               False
#
# [5 rows x 106 columns]

# %%
# build RNN that minimize MAE
